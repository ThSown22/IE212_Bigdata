# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
spark = SparkSession.builder.appName("DF_LAB_3").getOrCreate()

# %% [markdown]
# Bài 1: Hãy đọc dữ liệu từ các file csv, sử dụng tự suy ra kiểu dữ liệu cho mỗi cột.

# %%
read_csv = lambda path: spark.read.format("csv").options(
    header="true", inferSchema="true", delimiter=";"
).load(path)


orders = read_csv("data/Orders.csv")
customers = read_csv("data/Customer_List.csv")
order_items = read_csv("data/Order_Items.csv")
products = read_csv("data/Products.csv")
order_reviews = read_csv("data/Order_Reviews.csv")

# %%
orders.show(5)
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            Order_ID|     Customer_Trx_ID|Order_Status|Order_Purchase_Timestamp|  Order_Approved_At|Order_Delivered_Carrier_Date|Order_Delivered_Customer_Date|Order_Estimated_Delivery_Date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|     2023-10-02 10:56:00|2023-10-02 11:07:00|         2023-10-04 19:55:00|          2023-10-10 21:25:00|          2023-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|     2024-07-24 20:41:00|2024-07-26 03:24:00|         2024-07-26 14:31:00|          2024-08-07 15:27:00|          2024-08-13 00:00:00|
# |47770eb9100c2d0c4...|41ce2a54c0b03bf34...|   delivered|     2024-08-08 08:38:00|2024-08-08 08:55:00|         2024-08-08 13:50:00|          2024-08-17 18:06:00|          2024-09-04 00:00:00|
# |949d5b44dbf5de918...|f88197465ea7920ad...|   delivered|     2023-11-18 19:28:00|2023-11-18 19:45:00|         2023-11-22 13:39:00|          2023-12-02 00:28:00|          2023-12-15 00:00:00|
# |ad21c59c0840e6cb8...|8ab97904e6daea886...|   delivered|     2024-02-13 21:18:00|2024-02-13 22:20:00|         2024-02-14 19:46:00|          2024-02-16 18:17:00|          2024-02-26 00:00:00|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# only showing top 5 rows

# %%
customers.show(5)
# Out:
# +--------------------+--------------------+--------------+----------------+--------------------+-------------+----------------+---------------------+---+------+
# |     Customer_Trx_ID|       Subscriber_ID|Subscribe_Date|First_Order_Date|Customer_Postal_Code|Customer_City|Customer_Country|Customer_Country_Code|Age|Gender|
# +--------------------+--------------------+--------------+----------------+--------------------+-------------+----------------+---------------------+---+------+
# |1e959e1f5920cba43...|9765e039028279fd2...|    2023-07-08|      2023-07-09|            FR-75005|        Paris|          France|                   FR| 29|  Male|
# |9877437582f263da7...|a75e134e7eb6f96e2...|    2024-03-23|      2024-04-11|           PL-00-001|       Warsaw|          Poland|                   PL| 38|  Male|
# |fa6fbbb2080646aca...|2fdac27295500e820...|    2023-05-12|      2023-06-01|             NL-1012|    Amsterdam|     Netherlands|                   NL| 35|Female|
# |a4c9ff14ae7620126...|e9ab8fd8ea96c85be...|    2023-04-16|      2023-04-26|            IT-00144|         Rome|           Italy|                   IT| 62|  Male|
# |93d5e378ae2f72a07...|6384e6a7b02171761...|    2023-05-26|      2023-06-27|             NL-1011|    Amsterdam|     Netherlands|                   NL| 19|  Male|
# +--------------------+--------------------+--------------+----------------+--------------------+-------------+----------------+---------------------+---+------+
# only showing top 5 rows

# %%
order_items.show(5)
# Out:
# +--------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# |            Order_ID|Order_Item_ID|          Product_ID|           Seller_ID|Shipping_Limit_Date|Price|Freight_Value|
# +--------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# |00010242fe8c5a6d1...|            1|4244733e06e7ecb49...|48436dade18ac8b2b...|2023-09-19 09:45:00| 58.9|        13.29|
# |00018f77f2f0320c5...|            1|e5f2d52b802189ee6...|dd7ddc04e1b6c2c61...|2023-05-03 11:05:00|239.9|        19.93|
# |000229ec398224ef6...|            1|c777355d18b72b67a...|5b51032eddd242adc...|2024-01-18 14:48:00|199.0|        17.87|
# |00024acbcdf0a6daa...|            1|7634da152a4610f15...|9d7a1d34a50524090...|2024-08-15 10:10:00|12.99|        12.79|
# |00042b26cf59d7ce6...|            1|ac6c3623068f30de0...|df560393f3a51e745...|2023-02-13 13:57:00|199.9|        18.14|
# +--------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# only showing top 5 rows

# %%
products.show(5)
# Out:
# +--------------------+---------------------+-----------------+-----------------+-----------------+----------------+
# |          Product_ID|Product_Category_Name|Product_Weight_Gr|Product_Length_Cm|Product_Height_Cm|Product_Width_Cm|
# +--------------------+---------------------+-----------------+-----------------+-----------------+----------------+
# |1e9e8ef04dbcff454...|            Perfumery|              225|               16|               10|              14|
# |3aa071139cb16b67c...|                  Art|             1000|               30|               18|              20|
# |96bd76ec8810374ed...|       Sports_Leisure|              154|               18|                9|              15|
# |cef67bcfe19066a93...|                 Baby|              371|               26|                4|              26|
# |9dc1a7de274444849...|           Housewares|              625|               20|               17|              13|
# +--------------------+---------------------+-----------------+-----------------+-----------------+----------------+
# only showing top 5 rows

# %%
order_reviews.show(5)
# Out:
# +--------------------+--------------------+------------+-----------------------+-------------------------+--------------------+-----------------------+
# |           Review_ID|            Order_ID|Review_Score|Review_Comment_Title_En|Review_Comment_Message_En|Review_Creation_Date|Review_Answer_Timestamp|
# +--------------------+--------------------+------------+-----------------------+-------------------------+--------------------+-----------------------+
# |7bc2406110b926393...|73fc7af87114b3971...|           4|                   NULL|                     NULL|    2024-01-18 00:00|    2024-01-18 21:46:00|
# |80e641a11e56f04c1...|a548910a1c6147796...|           5|                   NULL|                     NULL|    2024-03-10 00:00|    2024-03-11 03:05:00|
# |228ce5500dc1d8e02...|f9e4b658b201a9f2e...|           5|                   NULL|                     NULL|    2024-02-17 00:00|    2024-02-18 14:36:00|
# |e64fb393e7b32834b...|658677c97b385a9be...|           5|                   NULL|     I received it wel...|    2023-04-21 00:00|    2023-04-21 22:02:00|
# |f7c4243c7fe1938f1...|8e6bfb81e283fa7e4...|           5|                   NULL|     Congratulations l...|    2024-03-01 00:00|    2024-03-02 10:26:00|
# +--------------------+--------------------+------------+-----------------------+-------------------------+--------------------+-----------------------+
# only showing top 5 rows

# %% [markdown]
# Câu 2: Thống kê tổng số đơn hàng, số lượng khách hàng và người bán.

# %%
# Tổng số đơn hàng
totalOrders = orders.select("Order_ID").distinct().count()
print("Tổng số đơn hàng:", totalOrders)

# Số lượng khách hàng
totalCustomers = customers.select("Customer_Trx_ID").distinct().count()
print("Số khách hàng:", totalCustomers)

# Số lượng người bán
totalSellers = order_items.select("Seller_ID").distinct().count()
print("Số người bán:", totalSellers)
# Out:
# Tổng số đơn hàng: 99441
# Số khách hàng: 99442
# Số người bán: 3095

# %% [markdown]
# Câu 3: Phân tích số lượng đơn hàng theo quốc gia, sắp xếp theo thứ tự giảm dần.

# %%
ordersByCountry = orders.join(customers, on='Customer_Trx_ID', how='inner')
orders_per_country = ordersByCountry.groupBy("Customer_Country")\
                                    .count()\
                                    .orderBy("count", ascending = False)

orders_per_country.show(9)
# Out:
# +----------------+-----+
# |Customer_Country|count|
# +----------------+-----+
# |         Germany|41754|
# |          France|12848|
# |     Netherlands|11629|
# |         Belgium| 5464|
# |         Austria| 5043|
# |     Switzerland| 3640|
# |  United Kingdom| 3382|
# |          Poland| 2139|
# |         Czechia| 2034|
# +----------------+-----+
# only showing top 9 rows

# %% [markdown]
# Câu 4: Phân tích số lượng đơn hàng nhóm theo năm, tháng đặt hàng (Hiển thị theo năm
# tăng dần, tháng giảm dần)

# %%
orders_with_time = orders.withColumn(
    "Order_Year", year("Order_Purchase_Timestamp")
).withColumn(
    "Order_Month", month("Order_Purchase_Timestamp")
)

# %%
orders_per_year_month = orders_with_time.groupBy(
    "Order_Year", "Order_Month"
).count()

# %%
orders_per_year_month = orders_per_year_month.orderBy(
    "Order_Year", ascending=True
).orderBy(
    "Order_Month", ascending=False
)

# %%
orders_per_year_month.show(9)
# Out:
# +----------+-----------+-----+
# |Order_Year|Order_Month|count|
# +----------+-----------+-----+
# |      2023|         12| 5673|
# |      2022|         12|    1|
# |      2023|         11| 7544|
# |      2022|         10|  324|
# |      2023|         10| 4631|
# |      2024|         10|    4|
# |      2023|          9| 4285|
# |      2024|          9|   16|
# |      2022|          9|    4|
# +----------+-----------+-----+
# only showing top 9 rows

# %% [markdown]
# Câu 5: Thống kê điểm đánh giá trung bình, số lượng đánh giá theo từng mức (ví dụ: 1 đến
# 5).

# %%
clean_reviews = order_reviews.withColumn(
    "Review_Score_int",
    col("Review_Score").cast("int")
).filter(
    col("Review_Score_int").between(1, 5)
)

clean_reviews.show(5)
# Out:
# +--------------------+--------------------+------------+-----------------------+-------------------------+--------------------+-----------------------+----------------+
# |           Review_ID|            Order_ID|Review_Score|Review_Comment_Title_En|Review_Comment_Message_En|Review_Creation_Date|Review_Answer_Timestamp|Review_Score_int|
# +--------------------+--------------------+------------+-----------------------+-------------------------+--------------------+-----------------------+----------------+
# |7bc2406110b926393...|73fc7af87114b3971...|           4|                   NULL|                     NULL|    2024-01-18 00:00|    2024-01-18 21:46:00|               4|
# |80e641a11e56f04c1...|a548910a1c6147796...|           5|                   NULL|                     NULL|    2024-03-10 00:00|    2024-03-11 03:05:00|               5|
# |228ce5500dc1d8e02...|f9e4b658b201a9f2e...|           5|                   NULL|                     NULL|    2024-02-17 00:00|    2024-02-18 14:36:00|               5|
# |e64fb393e7b32834b...|658677c97b385a9be...|           5|                   NULL|     I received it wel...|    2023-04-21 00:00|    2023-04-21 22:02:00|               5|
# |f7c4243c7fe1938f1...|8e6bfb81e283fa7e4...|           5|                   NULL|     Congratulations l...|    2024-03-01 00:00|    2024-03-02 10:26:00|               5|
# +--------------------+--------------------+------------+-----------------------+-------------------------+--------------------+-----------------------+----------------+
# only showing top 5 rows

# %%
review_stats = clean_reviews.groupBy("Review_Score_int") \
    .agg(
        count("*").alias("So_Luong_Danh_Gia"),
        avg("Review_Score_int").alias("Diem_Trung_Binh")
    ) \
    .orderBy("Review_Score_int")

review_stats.show()
# Out:
# +----------------+-----------------+---------------+
# |Review_Score_int|So_Luong_Danh_Gia|Diem_Trung_Binh|
# +----------------+-----------------+---------------+
# |               1|            11424|            1.0|
# |               2|             3151|            2.0|
# |               3|             8179|            3.0|
# |               4|            19141|            4.0|
# |               5|            57328|            5.0|
# +----------------+-----------------+---------------+

# %% [markdown]
# Bài 10: Xếp hạng các seller dựa trên tổng doanh thu và số lượng đơn hàng bán được.

# %%
orders_items_join = orders.join(
    order_items,
    on="Order_ID",
    how="inner"
)

orders_items_join.show(5)
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# |            Order_ID|     Customer_Trx_ID|Order_Status|Order_Purchase_Timestamp|  Order_Approved_At|Order_Delivered_Carrier_Date|Order_Delivered_Customer_Date|Order_Estimated_Delivery_Date|Order_Item_ID|          Product_ID|           Seller_ID|Shipping_Limit_Date|Price|Freight_Value|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# |00310b0c75bb13015...|0dad07848c618cc5a...|    canceled|     2024-08-15 14:29:00|2024-08-15 15:04:00|                        NULL|                         NULL|          2024-08-29 00:00:00|            1|c8e7c2ef329fcda4a...|a2deecd5398f5df49...|2024-08-17 15:04:00| 39.9|        15.38|
# |0032d07457ae9c806...|d356c20816dc75a30...|   delivered|     2024-03-10 18:53:00|2024-03-10 19:48:00|         2024-03-13 17:16:00|          2024-04-29 21:08:00|          2024-04-17 00:00:00|            1|08279c494018541f7...|e333046ce6517bd8b...|2024-03-15 19:28:00|159.0|        27.19|
# |0045e3085f083f0f3...|eb729faa993caad20...|   delivered|     2023-08-10 16:13:00|2023-08-11 07:15:00|         2023-08-16 18:27:00|          2023-08-29 20:03:00|          2023-08-30 00:00:00|            1|9545d45c37449ccbc...|431af27f296bc6519...|2023-08-17 07:15:00|116.9|        13.84|
# |007ff0b0f79be782f...|fc021f2dd664b4945...|   delivered|     2024-02-03 17:46:00|2024-02-03 20:10:00|         2024-02-06 18:28:00|          2024-02-14 20:27:00|          2024-03-02 00:00:00|            1|e819fddd6622f30e8...|7139dc5186aa238b0...|2024-02-08 20:10:00| 39.0|        16.11|
# |0094bd07f49fed902...|de0c1a4d8c367c58d...|   delivered|     2024-05-01 02:04:00|2024-05-03 04:12:00|         2024-05-10 19:19:00|          2024-05-16 21:12:00|          2024-05-14 00:00:00|            1|d64e758afad411049...|5670f4db5b62c43d5...|2024-05-09 04:12:00|11.53|         7.39|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# only showing top 5 rows

# %%
orders_items_revenue = orders_items_join.withColumn(
    "Revenue",
    col("Price") + col("Freight_Value")
)

orders_items_revenue.select(
    "Order_ID", "Seller_ID", "Revenue"
).show(5)
# Out:
# +--------------------+--------------------+------------------+
# |            Order_ID|           Seller_ID|           Revenue|
# +--------------------+--------------------+------------------+
# |00010242fe8c5a6d1...|48436dade18ac8b2b...|             72.19|
# |00018f77f2f0320c5...|dd7ddc04e1b6c2c61...|            259.83|
# |000229ec398224ef6...|5b51032eddd242adc...|            216.87|
# |00024acbcdf0a6daa...|9d7a1d34a50524090...|             25.78|
# |00042b26cf59d7ce6...|df560393f3a51e745...|218.04000000000002|
# +--------------------+--------------------+------------------+
# only showing top 5 rows

# %%
seller_stats = orders_items_revenue.groupBy("Seller_ID") \
    .agg(
        countDistinct("Order_ID").alias("So_Luong_Don_Hang"),
        sum("Revenue").alias("Tong_Doanh_Thu")
    )

# %%
seller_ranking = seller_stats.orderBy(
    col("Tong_Doanh_Thu").desc()
)

seller_ranking.show(9)
# Out:
# +--------------------+-----------------+------------------+
# |           Seller_ID|So_Luong_Don_Hang|    Tong_Doanh_Thu|
# +--------------------+-----------------+------------------+
# |4869f7a5dfa277a7d...|             1132|249640.69999999998|
# |7c67e1448b00f6e96...|              982|         239536.44|
# |53243585a1d6dc264...|              358|235856.67999999996|
# |4a3ca9315b744ce9f...|             1806|235539.95999999985|
# |fa1c13f2614d7b5c4...|              585|         204084.73|
# |da8622b14eb17ae28...|             1314|         185192.32|
# |7e93a43ef30c4f03f...|              336|         182754.05|
# |1025f0e2d44d7041d...|              915|172860.69000000003|
# |7a67c85e85bb2ce85...|             1160|162648.38000000003|
# +--------------------+-----------------+------------------+
# only showing top 9 rows
